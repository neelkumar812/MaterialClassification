# %%
import os
import tensorflow as tf
from tqdm import tqdm
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.optimizers import SGD, Adam
from sklearn.utils import shuffle

# %%
drive.mount("/content/drive")
os.chdir("/content/drive/My Drive")
if not os.path.exists('CZ4042_project'):
    os.makedirs('CZ4042_project')
os.chdir('CZ4042_project')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data acquisition
#
# Use obtain_fmd_minc_dataset.ipynb to download the FMD and MINC data to drive

# %% [markdown]
# # Load FMD data

# %%
x_train_fmd = []
y_train_fmd = []

label_map = {   
                "fabric":0,
                "foliage":1,
                "glass":2,
                "leather":3,
                "metal":4,
                "paper":5,
                "plastic":6,
                "stone":7,
                "water":8,
                "wood":9,
             }

dim = 256
dirs = os.listdir("FMD/image")
for class_dir in dirs:
  class_dir_path = os.path.join("FMD/image/", class_dir)
  num_loaded = 0
  for img_name in os.listdir(class_dir_path):
    if img_name[-3:] != 'jpg':
      continue
    img_path = os.path.join(class_dir_path, img_name)
    img = cv2.imread(img_path)
    targets = np.zeros(10)
    targets[label_map[class_dir]] = 1 
    x_train_fmd.append(cv2.resize(img, (dim, dim)))
    y_train_fmd.append(targets)
    num_loaded += 1
  print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_fmd = np.array(y_train_fmd, np.uint8)
x_train_fmd = np.array(x_train_fmd, np.float32)
# Out:
# load 100/101 images from foliage
# load 100/100 images from glass
# load 100/100 images from leather
# load 100/100 images from metal
# load 100/100 images from plastic
# load 100/100 images from paper
# load 100/100 images from water
# load 100/100 images from stone
# load 100/100 images from wood
# load 100/102 images from fabric

# %% [markdown]
# # Split FMD data into train, val and test

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_fmd, y_train_fmd):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_fmd, x_valid_test_fmd = x_train_fmd[train_index], x_train_fmd[none_train_index]
    y_train_fmd, y_valid_test_fmd = y_train_fmd[train_index], y_train_fmd[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_fmd, y_valid_test_fmd):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_fmd, x_test_fmd = x_valid_test_fmd[val_index], x_valid_test_fmd[test_index]
    y_val_fmd, y_test_fmd = y_valid_test_fmd[val_index], y_valid_test_fmd[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # Load MINC dataset

# %%
x_train_minc = []
y_train_minc = []
num_to_load_per_class = 100 # there are 2.5k images per class, we only use 100 here

dirs = os.listdir("MINC/minc-2500/images/")
for class_dir in dirs:
  if class_dir in label_map.keys():
    class_dir_path = os.path.join("MINC/minc-2500/images/", class_dir)
    num_loaded = 0
    for img_name in os.listdir(class_dir_path):
      if img_name[-3:] != 'jpg':
        continue
      img_path = os.path.join(class_dir_path, img_name)
      img = cv2.imread(img_path)
      targets = np.zeros(10)
      targets[label_map[class_dir]] = 1 
      x_train_minc.append(cv2.resize(img, (dim, dim)))
      y_train_minc.append(targets)
      num_loaded += 1
      if num_loaded == num_to_load_per_class:
        break
    print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_minc = np.array(y_train_minc, np.uint8)
x_train_minc = np.array(x_train_minc, np.float32)
# Out:
# load 100/2500 images from fabric
# load 100/2500 images from foliage
# load 100/2500 images from glass
# load 100/2500 images from leather
# load 100/2500 images from metal
# load 100/2500 images from paper
# load 100/2500 images from plastic
# load 100/2500 images from stone
# load 100/2500 images from wood
# load 100/2500 images from water

# %% [markdown]
# # Split MINC data into train, val and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_minc, y_train_minc):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_minc, x_valid_test_minc = x_train_minc[train_index], x_train_minc[none_train_index]
    y_train_minc, y_valid_test_minc = y_train_minc[train_index], y_train_minc[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_minc, y_valid_test_minc):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_minc, x_test_minc = x_valid_test_minc[val_index], x_valid_test_minc[test_index]
    y_val_minc, y_test_minc = y_valid_test_minc[val_index], y_valid_test_minc[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # obtain train and val data (using only FMD train and val data)

# %%
# merge train data
x_train = x_train_fmd
y_train = y_train_fmd
x_train, y_train = shuffle(x_train, y_train, random_state=7)
del y_train_minc
del x_train_minc
del y_train_fmd
del x_train_fmd

# merge val data
x_val = x_val_fmd
y_val = y_val_fmd
x_val, y_val = shuffle(x_val, y_val, random_state=7)
del y_val_minc
del x_val_minc
del y_val_fmd
del x_val_fmd

# %% [markdown]
# # Data augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,)
                            #height_shift_range=0.2,
                            #width_shift_range=0.2,
                            #horizontal_flip=True,)
                            #rotation_range=30,)
                            #brightness_range=[0.7,1.0],
                            #zoom_range=0.3)

val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # Load pretrained ResNet

# %%
res_model = tf.keras.applications.resnet_v2.ResNet152V2(
    include_top=False,
    weights="imagenet",
    input_shape=(dim, dim, 3),
)

print("number of layers:", len(res_model.layers))

# decide whether to freeze pretrained weights
for layer in res_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 11s 0us/step
# number of layers: 564

# %% [markdown]
# # Append custom Layers

# %%
x = res_model.output
x = Flatten()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
predictions = Dense(10, activation="softmax")(x)
model1 = Model(inputs=res_model.input, outputs=predictions)

# %% [markdown]
# # Fine tuning

# %%
epochs = 100
learning_rate = 0.001
batch_size = 32

callbacks = [ EarlyStopping(monitor='val_loss', patience=5, verbose=1), 
              ModelCheckpoint(filepath='weights.best.inc.resnet_fmd.hdf5', verbose=1, save_best_only=True),
             #ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
            ]

# %%
# compile the model
model1.compile(optimizer=SGD(lr=learning_rate, momentum=0.9)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
# ------ TRAINING ------
history = model1.fit(train_datagen.flow(x_train, y_train, batch_size=batch_size),
                  steps_per_epoch=len(x_train)/batch_size, 
                  validation_data=val_datagen.flow(x_val, y_val, batch_size=batch_size), 
                  validation_steps=len(x_val)/batch_size,
                  callbacks=callbacks,
                  epochs=epochs,
                  verbose=1)
# Out:
# Epoch 1/100
# 22/21 [==============================] - ETA: 0s - loss: 2.3982 - accuracy: 0.4429
# Epoch 1: val_loss improved from inf to 1.62942, saving model to weights.best.inc.optimized_resnet_fmd_minc.hdf5
# 21/21 [==============================] - 75s 3s/step - loss: 2.3982 - accuracy: 0.4429 - val_loss: 1.6294 - val_accuracy: 0.5920
# Epoch 2/100
# 22/21 [==============================] - ETA: 0s - loss: 0.4815 - accuracy: 0.8671
# Epoch 2: val_loss did not improve from 1.62942
# 21/21 [==============================] - 9s 395ms/step - loss: 0.4815 - accuracy: 0.8671 - val_loss: 1.8020 - val_accuracy: 0.6119
# Epoch 3/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.9286
# Epoch 3: val_loss improved from 1.62942 to 1.53627, saving model to weights.best.inc.optimized_resnet_fmd_minc.hdf5
# 21/21 [==============================] - 15s 724ms/step - loss: 0.2783 - accuracy: 0.9286 - val_loss: 1.5363 - val_accuracy: 0.6816
# Epoch 4/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9614
# Epoch 4: val_loss did not improve from 1.53627
# 21/21 [==============================] - 9s 404ms/step - loss: 0.1303 - accuracy: 0.9614 - val_loss: 1.6316 - val_accuracy: 0.6418
# Epoch 5/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9743
# Epoch 5: val_loss did not improve from 1.53627
# 21/21 [==============================] - 9s 414ms/step - loss: 0.0914 - accuracy: 0.9743 - val_loss: 1.6047 - val_accuracy: 0.7114
# Epoch 6/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9714
# Epoch 6: val_loss improved from 1.53627 to 1.41069, saving model to weights.best.inc.optimized_resnet_fmd_minc.hdf5
# 21/21 [==============================] - 16s 738ms/step - loss: 0.1010 - accuracy: 0.9714 - val_loss: 1.4107 - val_accuracy: 0.7114
# Epoch 7/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9871
# Epoch 7: val_loss improved from 1.41069 to 1.34820, saving model to weights.best.inc.optimized_resnet_fmd_minc.hdf5
# 21/21 [==============================] - 17s 796ms/step - loss: 0.0421 - accuracy: 0.9871 - val_loss: 1.3482 - val_accuracy: 0.7214
# Epoch 8/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9900
# Epoch 8: val_loss improved from 1.34820 to 1.29001, saving model to weights.best.inc.optimized_resnet_fmd_minc.hdf5
# 21/21 [==============================] - 16s 752ms/step - loss: 0.0372 - accuracy: 0.9900 - val_loss: 1.2900 - val_accuracy: 0.7512
# Epoch 9/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9886
# Epoch 9: val_loss did not improve from 1.29001
# 21/21 [==============================] - 10s 444ms/step - loss: 0.0231 - accuracy: 0.9886 - val_loss: 1.3506 - val_accuracy: 0.7214
# Epoch 10/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9971
# Epoch 10: val_loss did not improve from 1.29001
# 21/21 [==============================] - 10s 460ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 1.4726 - val_accuracy: 0.7164
# Epoch 11/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9986
# Epoch 11: val_loss did not improve from 1.29001
# 21/21 [==============================] - 10s 459ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 1.3363 - val_accuracy: 0.7264
# Epoch 12/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9943
# Epoch 12: val_loss did not improve from 1.29001
# 21/21 [==============================] - 10s 451ms/step - loss: 0.0220 - accuracy: 0.9943 - val_loss: 1.3051 - val_accuracy: 0.7214
# Epoch 13/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9986
# Epoch 13: val_loss did not improve from 1.29001
# 21/21 [==============================] - 10s 441ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 1.3627 - val_accuracy: 0.7313
# Epoch 13: early stopping

# %%
import matplotlib.pyplot as plt

def plot_metric(model_, metric, save=False, save_path=None):
    train_metrics = model_.history.history[metric]
    val_metrics = model_.history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    if save:
      plt.savefig(save_path)
    plt.show()

# %%
plot_metric(model1, 'loss')

# %%
plot_metric(model1, 'accuracy')

# %% [markdown]
# # Evaluation on test data

# %%
# evaluate on fmd test data
model1.evaluate(val_datagen.flow(x_test_fmd, y_test_fmd, batch_size=batch_size))
# Out:
# 4/4 [==============================] - 2s 437ms/step - loss: 1.1282 - accuracy: 0.7475
# [1.128180742263794, 0.747474730014801]

# %%
# evaluate on minc test data
model1.evaluate(val_datagen.flow(x_test_minc, y_test_minc, batch_size=batch_size))
# Out:
# 4/4 [==============================] - 1s 238ms/step - loss: 2.1998 - accuracy: 0.4343
# [2.1997947692871094, 0.4343434274196625]

# %%
# evaluate on minc + fmd test data
x_test = np.concatenate((x_test_fmd, x_test_minc))
y_test = np.concatenate((y_test_fmd, y_test_minc))

model1.evaluate(val_datagen.flow(x_test, y_test, batch_size=batch_size))
# Out:
# 7/7 [==============================] - 3s 386ms/step - loss: 1.6640 - accuracy: 0.5909
# [1.6639882326126099, 0.5909090638160706]
