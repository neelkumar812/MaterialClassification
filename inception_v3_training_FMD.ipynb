# %% [markdown]
# # Setup environment

# %%
import os
from tqdm import tqdm
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.optimizers import SGD, Adam
from sklearn.utils import shuffle

# %%
drive.mount("/content/gdrive")
os.chdir('gdrive/MyDrive')
if not os.path.exists('CZ4042_project'):
    os.makedirs('CZ4042_project')
os.chdir('CZ4042_project')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Data acquisition
#
# Use obtain_fmd_minc_dataset.ipynb to download the FMD and MINC data to drive

# %% [markdown]
# # Load FMD data

# %%
x_train_fmd = []
y_train_fmd = []

label_map = {   
                "fabric":0,
                "foliage":1,
                "glass":2,
                "leather":3,
                "metal":4,
                "paper":5,
                "plastic":6,
                "stone":7,
                "water":8,
                "wood":9,
             }

dim = 256
dirs = os.listdir("FMD/image")
for class_dir in dirs:
  class_dir_path = os.path.join("FMD/image/", class_dir)
  num_loaded = 0
  for img_name in os.listdir(class_dir_path):
    if img_name[-3:] != 'jpg':
      continue
    img_path = os.path.join(class_dir_path, img_name)
    img = cv2.imread(img_path)
    targets = np.zeros(10)
    targets[label_map[class_dir]] = 1 
    x_train_fmd.append(cv2.resize(img, (dim, dim)))
    y_train_fmd.append(targets)
    num_loaded += 1
  print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_fmd = np.array(y_train_fmd, np.uint8)
x_train_fmd = np.array(x_train_fmd, np.float32)
# Out:
# load 100/101 images from foliage
# load 100/100 images from leather
# load 100/100 images from glass
# load 100/100 images from metal
# load 100/100 images from paper
# load 100/100 images from plastic
# load 100/100 images from water
# load 100/100 images from stone
# load 100/100 images from wood
# load 100/102 images from fabric

# %% [markdown]
# # Split FMD data into train, val and test

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_fmd, y_train_fmd):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_fmd, x_valid_test_fmd = x_train_fmd[train_index], x_train_fmd[none_train_index]
    y_train_fmd, y_valid_test_fmd = y_train_fmd[train_index], y_train_fmd[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_fmd, y_valid_test_fmd):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_fmd, x_test_fmd = x_valid_test_fmd[val_index], x_valid_test_fmd[test_index]
    y_val_fmd, y_test_fmd = y_valid_test_fmd[val_index], y_valid_test_fmd[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # Load MINC dataset

# %%
x_train_minc = []
y_train_minc = []
num_to_load_per_class = 100 # there are 2.5k images per class, we only use 100 here

dirs = os.listdir("MINC/minc-2500/images/")
for class_dir in dirs:
  if class_dir in label_map.keys():
    class_dir_path = os.path.join("MINC/minc-2500/images/", class_dir)
    num_loaded = 0
    for img_name in os.listdir(class_dir_path):
      if img_name[-3:] != 'jpg':
        continue
      img_path = os.path.join(class_dir_path, img_name)
      img = cv2.imread(img_path)
      targets = np.zeros(10)
      targets[label_map[class_dir]] = 1 
      x_train_minc.append(cv2.resize(img, (dim, dim)))
      y_train_minc.append(targets)
      num_loaded += 1
      if num_loaded == num_to_load_per_class:
        break
    print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_minc = np.array(y_train_minc, np.uint8)
x_train_minc = np.array(x_train_minc, np.float32)
# Out:
# load 100/2500 images from paper
# load 100/2500 images from plastic
# load 100/2500 images from stone
# load 100/2500 images from water
# load 100/2500 images from wood
# load 100/2500 images from fabric
# load 100/2500 images from foliage
# load 100/2500 images from glass
# load 100/2500 images from leather
# load 100/2500 images from metal

# %% [markdown]
# # Split MINC data into train, val and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_minc, y_train_minc):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_minc, x_valid_test_minc = x_train_minc[train_index], x_train_minc[none_train_index]
    y_train_minc, y_valid_test_minc = y_train_minc[train_index], y_train_minc[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_minc, y_valid_test_minc):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_minc, x_test_minc = x_valid_test_minc[val_index], x_valid_test_minc[test_index]
    y_val_minc, y_test_minc = y_valid_test_minc[val_index], y_valid_test_minc[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # obtain train and val data (using only FMD train and val data)

# %%
# define final train data
x_train = x_train_fmd
y_train = y_train_fmd
del y_train_minc
del x_train_minc
del y_train_fmd
del x_train_fmd

# define final val data
x_val = x_val_fmd
y_val = y_val_fmd
del y_val_minc
del x_val_minc
del y_val_fmd
del x_val_fmd

# %% [markdown]
# # Data augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,)
                            #height_shift_range=0.2,
                            #width_shift_range=0.2,
                            #horizontal_flip=True,
                            #rotation_range=30,
                            #brightness_range=[0.7,1.0],
                            #zoom_range=0.3)

val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # Load pretrained InceptionV3 (imagenet)

# %%
inc_model = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(dim, dim, 3))

print("number of layers:", len(inc_model.layers))

# decide whether to freeze pretrained weights
for layer in inc_model.layers:
    layer.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 6s 0us/step
# number of layers: 311

# %% [markdown]
# # Append custom Layers

# %%
x = inc_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
predictions = Dense(10, activation="softmax")(x)
model_ = Model(inputs=inc_model.input, outputs=predictions)

# %% [markdown]
# # Fine tuning

# %%
epochs = 100
learning_rate = 0.001
batch_size = 32

callbacks = [ EarlyStopping(monitor='val_loss', patience=5, verbose=1), 
              ModelCheckpoint(filepath='weights.best.inc.fmd.hdf5', verbose=1, save_best_only=True),
             #ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
            ]

# %%
# compile the model
model_.compile(optimizer=SGD(lr=learning_rate, momentum=0.9)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
# ------ TRAINING ------
model_.fit_generator(train_datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(x_train)/batch_size, 
                    validation_data=val_datagen.flow(x_val, y_val, batch_size=batch_size), 
                    validation_steps=len(x_val)/batch_size,
                    callbacks=callbacks,
                    epochs=epochs,
                    verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/100
# 22/21 [==============================] - ETA: 0s - loss: 2.3440 - accuracy: 0.1371
# Epoch 1: val_loss improved from inf to 2.16403, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 36s 915ms/step - loss: 2.3440 - accuracy: 0.1371 - val_loss: 2.1640 - val_accuracy: 0.1841
# Epoch 2/100
# 22/21 [==============================] - ETA: 0s - loss: 2.0972 - accuracy: 0.2600
# Epoch 2: val_loss improved from 2.16403 to 1.91707, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 8s 388ms/step - loss: 2.0972 - accuracy: 0.2600 - val_loss: 1.9171 - val_accuracy: 0.4627
# Epoch 3/100
# 22/21 [==============================] - ETA: 0s - loss: 1.7639 - accuracy: 0.5286
# Epoch 3: val_loss improved from 1.91707 to 1.63864, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 405ms/step - loss: 1.7639 - accuracy: 0.5286 - val_loss: 1.6386 - val_accuracy: 0.6119
# Epoch 4/100
# 22/21 [==============================] - ETA: 0s - loss: 1.4107 - accuracy: 0.6957
# Epoch 4: val_loss improved from 1.63864 to 1.34320, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 420ms/step - loss: 1.4107 - accuracy: 0.6957 - val_loss: 1.3432 - val_accuracy: 0.6915
# Epoch 5/100
# 22/21 [==============================] - ETA: 0s - loss: 0.9951 - accuracy: 0.8200
# Epoch 5: val_loss improved from 1.34320 to 1.10928, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 393ms/step - loss: 0.9951 - accuracy: 0.8200 - val_loss: 1.1093 - val_accuracy: 0.7114
# Epoch 6/100
# 22/21 [==============================] - ETA: 0s - loss: 0.6835 - accuracy: 0.8529
# Epoch 6: val_loss improved from 1.10928 to 0.97128, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 395ms/step - loss: 0.6835 - accuracy: 0.8529 - val_loss: 0.9713 - val_accuracy: 0.7164
# Epoch 7/100
# 22/21 [==============================] - ETA: 0s - loss: 0.4677 - accuracy: 0.9229
# Epoch 7: val_loss improved from 0.97128 to 0.87662, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 398ms/step - loss: 0.4677 - accuracy: 0.9229 - val_loss: 0.8766 - val_accuracy: 0.7264
# Epoch 8/100
# 22/21 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.9514
# Epoch 8: val_loss improved from 0.87662 to 0.81976, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 397ms/step - loss: 0.3087 - accuracy: 0.9514 - val_loss: 0.8198 - val_accuracy: 0.7463
# Epoch 9/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9657
# Epoch 9: val_loss improved from 0.81976 to 0.80331, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 400ms/step - loss: 0.2490 - accuracy: 0.9657 - val_loss: 0.8033 - val_accuracy: 0.7264
# Epoch 10/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1719 - accuracy: 0.9714
# Epoch 10: val_loss improved from 0.80331 to 0.80255, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 400ms/step - loss: 0.1719 - accuracy: 0.9714 - val_loss: 0.8026 - val_accuracy: 0.7114
# Epoch 11/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9900
# Epoch 11: val_loss improved from 0.80255 to 0.80176, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 403ms/step - loss: 0.1322 - accuracy: 0.9900 - val_loss: 0.8018 - val_accuracy: 0.7264
# Epoch 12/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9900
# Epoch 12: val_loss improved from 0.80176 to 0.78374, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 9s 399ms/step - loss: 0.1065 - accuracy: 0.9900 - val_loss: 0.7837 - val_accuracy: 0.7313
# Epoch 13/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9900
# Epoch 13: val_loss improved from 0.78374 to 0.78037, saving model to weights.best.inc.fmd_minc.hdf5
# 21/21 [==============================] - 10s 449ms/step - loss: 0.0964 - accuracy: 0.9900 - val_loss: 0.7804 - val_accuracy: 0.7463
# Epoch 14/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9957
# Epoch 14: val_loss did not improve from 0.78037
# 21/21 [==============================] - 8s 343ms/step - loss: 0.0560 - accuracy: 0.9957 - val_loss: 0.7919 - val_accuracy: 0.7413
# Epoch 15/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9929
# Epoch 15: val_loss did not improve from 0.78037
# 21/21 [==============================] - 8s 344ms/step - loss: 0.0725 - accuracy: 0.9929 - val_loss: 0.7976 - val_accuracy: 0.7363
# Epoch 16/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9929
# Epoch 16: val_loss did not improve from 0.78037
# 21/21 [==============================] - 8s 345ms/step - loss: 0.0601 - accuracy: 0.9929 - val_loss: 0.8109 - val_accuracy: 0.7413
# Epoch 17/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9943
# Epoch 17: val_loss did not improve from 0.78037
# 21/21 [==============================] - 8s 347ms/step - loss: 0.0440 - accuracy: 0.9943 - val_loss: 0.8020 - val_accuracy: 0.7214
# Epoch 18/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9971
# Epoch 18: val_loss did not improve from 0.78037
# 21/21 [==============================] - 8s 347ms/step - loss: 0.0409 - accuracy: 0.9971 - val_loss: 0.8180 - val_accuracy: 0.7264
# Epoch 18: early stopping

# %%
import matplotlib.pyplot as plt

def plot_metric(model_, metric, save=False, save_path=None):
    train_metrics = model_.history.history[metric]
    val_metrics = model_.history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    if save:
      plt.savefig(save_path)
    plt.show()

# %%
plot_metric(model_, 'loss')

# %%
plot_metric(model_, 'accuracy')

# %% [markdown]
# # Evaluation on test data

# %%
# evaluate on fmd test data
model_.evaluate(val_datagen.flow(x_test_fmd, y_test_fmd, batch_size=batch_size))
# Out:
# 4/4 [==============================] - 1s 310ms/step - loss: 0.6311 - accuracy: 0.7980
# [0.6311171054840088, 0.7979797720909119]

# %%
# evaluate on minc test data
model_.evaluate(val_datagen.flow(x_test_minc, y_test_minc, batch_size=batch_size))
# Out:
# 4/4 [==============================] - 0s 69ms/step - loss: 1.8661 - accuracy: 0.3636
# [1.8660537004470825, 0.3636363744735718]

# %%
# evaluate on minc + fmd test data
x_test = np.concatenate((x_test_fmd, x_test_minc))
y_test = np.concatenate((y_test_fmd, y_test_minc))

model_.evaluate(val_datagen.flow(x_test, y_test, batch_size=batch_size))
# Out:
# 7/7 [==============================] - 1s 213ms/step - loss: 1.2486 - accuracy: 0.5808
# [1.248584270477295, 0.5808081030845642]
