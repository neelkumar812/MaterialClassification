# %%
import os
from tqdm import tqdm
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.optimizers import SGD, Adam
from sklearn.utils import shuffle

# %%
drive.mount("/content/gdrive")
os.chdir('gdrive/MyDrive')
if not os.path.exists('CZ4042_project'):
    os.makedirs('CZ4042_project')
os.chdir('CZ4042_project')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Data acquisition
#
# Use obtain_fmd_minc_dataset.ipynb to download the FMD and MINC data to drive

# %% [markdown]
# # Load FMD data

# %%
x_train_fmd = []
y_train_fmd = []

label_map = {   
                "fabric":0,
                "foliage":1,
                "glass":2,
                "leather":3,
                "metal":4,
                "paper":5,
                "plastic":6,
                "stone":7,
                "water":8,
                "wood":9,
             }

dim = 256
dirs = os.listdir("FMD/image")
for class_dir in dirs:
  class_dir_path = os.path.join("FMD/image/", class_dir)
  num_loaded = 0
  for img_name in os.listdir(class_dir_path):
    if img_name[-3:] != 'jpg':
      continue
    img_path = os.path.join(class_dir_path, img_name)
    img = cv2.imread(img_path)
    targets = np.zeros(10)
    targets[label_map[class_dir]] = 1 
    x_train_fmd.append(cv2.resize(img, (dim, dim)))
    y_train_fmd.append(targets)
    num_loaded += 1
  print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_fmd = np.array(y_train_fmd, np.uint8)
x_train_fmd = np.array(x_train_fmd, np.float32)
# Out:
# load 100/101 images from foliage
# load 100/100 images from glass
# load 100/100 images from leather
# load 100/100 images from metal
# load 100/100 images from paper
# load 100/100 images from plastic
# load 100/100 images from stone
# load 100/100 images from water
# load 100/100 images from wood
# load 100/102 images from fabric

# %% [markdown]
# # Split FMD data into train, val and test

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_fmd, y_train_fmd):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_fmd, x_valid_test_fmd = x_train_fmd[train_index], x_train_fmd[none_train_index]
    y_train_fmd, y_valid_test_fmd = y_train_fmd[train_index], y_train_fmd[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_fmd, y_valid_test_fmd):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_fmd, x_test_fmd = x_valid_test_fmd[val_index], x_valid_test_fmd[test_index]
    y_val_fmd, y_test_fmd = y_valid_test_fmd[val_index], y_valid_test_fmd[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # Split FMD data into train, val and test

# %%
x_train_minc = []
y_train_minc = []
num_to_load_per_class = 100 # there are 2.5k images per class, we only use 100 here

dirs = os.listdir("MINC/minc-2500/images/")
for class_dir in dirs:
  if class_dir in label_map.keys():
    class_dir_path = os.path.join("MINC/minc-2500/images/", class_dir)
    num_loaded = 0
    for img_name in os.listdir(class_dir_path):
      if img_name[-3:] != 'jpg':
        continue
      img_path = os.path.join(class_dir_path, img_name)
      img = cv2.imread(img_path)
      targets = np.zeros(10)
      targets[label_map[class_dir]] = 1 
      x_train_minc.append(cv2.resize(img, (dim, dim)))
      y_train_minc.append(targets)
      num_loaded += 1
      if num_loaded == num_to_load_per_class:
        break
    print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_minc = np.array(y_train_minc, np.uint8)
x_train_minc = np.array(x_train_minc, np.float32)
# Out:
# load 100/2500 images from paper
# load 100/2500 images from plastic
# load 100/2500 images from stone
# load 100/2500 images from water
# load 100/2500 images from wood
# load 100/2500 images from fabric
# load 100/2500 images from foliage
# load 100/2500 images from glass
# load 100/2500 images from leather
# load 100/2500 images from metal

# %% [markdown]
# # Split MINC data into train, val and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_minc, y_train_minc):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_minc, x_valid_test_minc = x_train_minc[train_index], x_train_minc[none_train_index]
    y_train_minc, y_valid_test_minc = y_train_minc[train_index], y_train_minc[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_minc, y_valid_test_minc):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_minc, x_test_minc = x_valid_test_minc[val_index], x_valid_test_minc[test_index]
    y_val_minc, y_test_minc = y_valid_test_minc[val_index], y_valid_test_minc[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # Merge MINC and FMD train/val data
#
# ---

# %%
# merge train data
x_train = np.concatenate((x_train_fmd, x_train_minc))
y_train = np.concatenate((y_train_fmd, y_train_minc))
x_train, y_train = shuffle(x_train, y_train, random_state=7)
del y_train_minc
del x_train_minc
del y_train_fmd
del x_train_fmd

# merge val data
x_val = np.concatenate((x_val_fmd, x_val_minc))
y_val = np.concatenate((y_val_fmd, y_val_minc))
x_val, y_val = shuffle(x_val, y_val, random_state=7)
del y_val_minc
del x_val_minc
del y_val_fmd
del x_val_fmd

# %% [markdown]
# # Data augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   #zoom_range=0.3,
                            #height_shift_range=0.2,
                            #width_shift_range=0.2,
                            horizontal_flip=True)
                            #rotation_range=30,
                            #brightness_range=[0.7,1.0])
                            

val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # Load pretrained MobileNetV2 (imagenet)

# %%
inc_model = MobileNetV2(weights='imagenet',
                        include_top=False,
                        input_shape=(dim, dim, 3))

print("number of layers:", len(inc_model.layers))

# decide whether to freeze pretrained weights
for layer in inc_model.layers:
    layer.trainable = True
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# number of layers: 154

# %% [markdown]
# #Append custom Layers

# %%
x = inc_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation="relu")(x)
#x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
#x = Dense(256, activation = "relu")(x)
predictions = Dense(10, activation="softmax")(x)
model_ = Model(inputs=inc_model.input, outputs=predictions)

# %% [markdown]
# # Fine tuning

# %%
epochs = 100
learning_rate = 0.001
batch_size = 128

callbacks = [ EarlyStopping(monitor='val_loss', patience=10, verbose=1), 
              ModelCheckpoint(filepath='weights.best.inc.fmd_minc.hdf5', verbose=1, save_best_only=True),
             #ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
            ]

# %%
# compile the model
model_.compile(optimizer=SGD(lr=learning_rate, momentum=0.9)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
# ------ TRAINING ------
model_.fit_generator(train_datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(x_train)/batch_size, 
                    validation_data=val_datagen.flow(x_val, y_val, batch_size=batch_size), 
                    validation_steps=len(x_val)/batch_size,
                    callbacks=callbacks,
                    epochs=epochs,
                    verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/100
# 11/10 [==============================] - ETA: 0s - loss: 2.3711 - accuracy: 0.1057
# Epoch 1: val_loss improved from inf to 2.29896, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 26s 2s/step - loss: 2.3711 - accuracy: 0.1057 - val_loss: 2.2990 - val_accuracy: 0.1119
# Epoch 2/100
# 11/10 [==============================] - ETA: 0s - loss: 2.1585 - accuracy: 0.2500
# Epoch 2: val_loss improved from 2.29896 to 2.15709, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 2.1585 - accuracy: 0.2500 - val_loss: 2.1571 - val_accuracy: 0.2289
# Epoch 3/100
# 11/10 [==============================] - ETA: 0s - loss: 1.9577 - accuracy: 0.4421
# Epoch 3: val_loss improved from 2.15709 to 2.03207, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 1.9577 - accuracy: 0.4421 - val_loss: 2.0321 - val_accuracy: 0.3383
# Epoch 4/100
# 11/10 [==============================] - ETA: 0s - loss: 1.7464 - accuracy: 0.5821
# Epoch 4: val_loss improved from 2.03207 to 1.91551, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 1.7464 - accuracy: 0.5821 - val_loss: 1.9155 - val_accuracy: 0.3905
# Epoch 5/100
# 11/10 [==============================] - ETA: 0s - loss: 1.5307 - accuracy: 0.6821
# Epoch 5: val_loss improved from 1.91551 to 1.80989, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 15s 1s/step - loss: 1.5307 - accuracy: 0.6821 - val_loss: 1.8099 - val_accuracy: 0.4403
# Epoch 6/100
# 11/10 [==============================] - ETA: 0s - loss: 1.3054 - accuracy: 0.7486
# Epoch 6: val_loss improved from 1.80989 to 1.69554, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 1.3054 - accuracy: 0.7486 - val_loss: 1.6955 - val_accuracy: 0.4726
# Epoch 7/100
# 11/10 [==============================] - ETA: 0s - loss: 1.1237 - accuracy: 0.7814
# Epoch 7: val_loss improved from 1.69554 to 1.58610, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 1.1237 - accuracy: 0.7814 - val_loss: 1.5861 - val_accuracy: 0.5149
# Epoch 8/100
# 11/10 [==============================] - ETA: 0s - loss: 0.9457 - accuracy: 0.8193
# Epoch 8: val_loss improved from 1.58610 to 1.49099, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.9457 - accuracy: 0.8193 - val_loss: 1.4910 - val_accuracy: 0.5323
# Epoch 9/100
# 11/10 [==============================] - ETA: 0s - loss: 0.7887 - accuracy: 0.8500
# Epoch 9: val_loss improved from 1.49099 to 1.41990, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.7887 - accuracy: 0.8500 - val_loss: 1.4199 - val_accuracy: 0.5473
# Epoch 10/100
# 11/10 [==============================] - ETA: 0s - loss: 0.6806 - accuracy: 0.8714
# Epoch 10: val_loss improved from 1.41990 to 1.35412, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.6806 - accuracy: 0.8714 - val_loss: 1.3541 - val_accuracy: 0.5721
# Epoch 11/100
# 11/10 [==============================] - ETA: 0s - loss: 0.5903 - accuracy: 0.8864
# Epoch 11: val_loss improved from 1.35412 to 1.30351, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.5903 - accuracy: 0.8864 - val_loss: 1.3035 - val_accuracy: 0.5821
# Epoch 12/100
# 11/10 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.9100
# Epoch 12: val_loss improved from 1.30351 to 1.27330, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.4947 - accuracy: 0.9100 - val_loss: 1.2733 - val_accuracy: 0.5796
# Epoch 13/100
# 11/10 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.9314
# Epoch 13: val_loss improved from 1.27330 to 1.24189, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.4296 - accuracy: 0.9314 - val_loss: 1.2419 - val_accuracy: 0.5846
# Epoch 14/100
# 11/10 [==============================] - ETA: 0s - loss: 0.3723 - accuracy: 0.9371
# Epoch 14: val_loss improved from 1.24189 to 1.20859, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.3723 - accuracy: 0.9371 - val_loss: 1.2086 - val_accuracy: 0.5945
# Epoch 15/100
# 11/10 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.9586
# Epoch 15: val_loss improved from 1.20859 to 1.18578, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.3137 - accuracy: 0.9586 - val_loss: 1.1858 - val_accuracy: 0.6020
# Epoch 16/100
# 11/10 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.9650
# Epoch 16: val_loss improved from 1.18578 to 1.16220, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.2699 - accuracy: 0.9650 - val_loss: 1.1622 - val_accuracy: 0.6244
# Epoch 17/100
# 11/10 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9736
# Epoch 17: val_loss improved from 1.16220 to 1.14790, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.2344 - accuracy: 0.9736 - val_loss: 1.1479 - val_accuracy: 0.6269
# Epoch 18/100
# 11/10 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9829
# Epoch 18: val_loss improved from 1.14790 to 1.12820, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.2012 - accuracy: 0.9829 - val_loss: 1.1282 - val_accuracy: 0.6318
# Epoch 19/100
# 11/10 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9850
# Epoch 19: val_loss improved from 1.12820 to 1.12742, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.1821 - accuracy: 0.9850 - val_loss: 1.1274 - val_accuracy: 0.6318
# Epoch 20/100
# 11/10 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9921
# Epoch 20: val_loss improved from 1.12742 to 1.11658, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.1542 - accuracy: 0.9921 - val_loss: 1.1166 - val_accuracy: 0.6368
# Epoch 21/100
# 11/10 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9929
# Epoch 21: val_loss improved from 1.11658 to 1.10284, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.1363 - accuracy: 0.9929 - val_loss: 1.1028 - val_accuracy: 0.6418
# Epoch 22/100
# 11/10 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9971
# Epoch 22: val_loss improved from 1.10284 to 1.10123, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.1183 - accuracy: 0.9971 - val_loss: 1.1012 - val_accuracy: 0.6418
# Epoch 23/100
# 11/10 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.9971
# Epoch 23: val_loss improved from 1.10123 to 1.09550, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.1077 - accuracy: 0.9971 - val_loss: 1.0955 - val_accuracy: 0.6443
# Epoch 24/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9986
# Epoch 24: val_loss improved from 1.09550 to 1.09412, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0918 - accuracy: 0.9986 - val_loss: 1.0941 - val_accuracy: 0.6418
# Epoch 25/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9993
# Epoch 25: val_loss improved from 1.09412 to 1.08918, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0831 - accuracy: 0.9993 - val_loss: 1.0892 - val_accuracy: 0.6318
# Epoch 26/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 1.0000
# Epoch 26: val_loss improved from 1.08918 to 1.07437, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0745 - accuracy: 1.0000 - val_loss: 1.0744 - val_accuracy: 0.6393
# Epoch 27/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9979
# Epoch 27: val_loss improved from 1.07437 to 1.06390, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0724 - accuracy: 0.9979 - val_loss: 1.0639 - val_accuracy: 0.6443
# Epoch 28/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 1.0000
# Epoch 28: val_loss improved from 1.06390 to 1.06200, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0642 - accuracy: 1.0000 - val_loss: 1.0620 - val_accuracy: 0.6343
# Epoch 29/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9993
# Epoch 29: val_loss improved from 1.06200 to 1.05596, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0584 - accuracy: 0.9993 - val_loss: 1.0560 - val_accuracy: 0.6418
# Epoch 30/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 1.0000
# Epoch 30: val_loss improved from 1.05596 to 1.04951, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 1.0495 - val_accuracy: 0.6418
# Epoch 31/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 1.0000
# Epoch 31: val_loss improved from 1.04951 to 1.04297, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 1.0430 - val_accuracy: 0.6468
# Epoch 32/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 1.0000
# Epoch 32: val_loss improved from 1.04297 to 1.03357, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 1.0336 - val_accuracy: 0.6468
# Epoch 33/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 1.0000
# Epoch 33: val_loss improved from 1.03357 to 1.02916, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 1.0292 - val_accuracy: 0.6493
# Epoch 34/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 1.0000
# Epoch 34: val_loss improved from 1.02916 to 1.02564, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 1.0256 - val_accuracy: 0.6493
# Epoch 35/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 1.0000
# Epoch 35: val_loss improved from 1.02564 to 1.01693, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 1.0169 - val_accuracy: 0.6493
# Epoch 36/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 1.0000
# Epoch 36: val_loss improved from 1.01693 to 1.01125, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 1.0112 - val_accuracy: 0.6493
# Epoch 37/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 1.01125
# 10/10 [==============================] - 12s 1s/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 1.0130 - val_accuracy: 0.6542
# Epoch 38/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 1.0000
# Epoch 38: val_loss improved from 1.01125 to 1.01000, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 1.0100 - val_accuracy: 0.6567
# Epoch 39/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 1.0000
# Epoch 39: val_loss improved from 1.01000 to 1.00681, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 1.0068 - val_accuracy: 0.6542
# Epoch 40/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 1.0000
# Epoch 40: val_loss improved from 1.00681 to 0.99801, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.9980 - val_accuracy: 0.6592
# Epoch 41/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 1.0000
# Epoch 41: val_loss improved from 0.99801 to 0.99027, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.9903 - val_accuracy: 0.6642
# Epoch 42/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.0000
# Epoch 42: val_loss improved from 0.99027 to 0.98566, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.9857 - val_accuracy: 0.6692
# Epoch 43/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9993
# Epoch 43: val_loss did not improve from 0.98566
# 10/10 [==============================] - 13s 1s/step - loss: 0.0238 - accuracy: 0.9993 - val_loss: 0.9858 - val_accuracy: 0.6617
# Epoch 44/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.98566
# 10/10 [==============================] - 12s 1s/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.9867 - val_accuracy: 0.6592
# Epoch 45/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.98566 to 0.98087, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.9809 - val_accuracy: 0.6592
# Epoch 46/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 1.0000
# Epoch 46: val_loss improved from 0.98087 to 0.97764, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.9776 - val_accuracy: 0.6592
# Epoch 47/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 1.0000
# Epoch 47: val_loss improved from 0.97764 to 0.97143, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.9714 - val_accuracy: 0.6617
# Epoch 48/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.97143 to 0.96741, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.9674 - val_accuracy: 0.6642
# Epoch 49/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 1.0000
# Epoch 49: val_loss improved from 0.96741 to 0.96516, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.9652 - val_accuracy: 0.6667
# Epoch 50/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 50: val_loss improved from 0.96516 to 0.96075, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.9608 - val_accuracy: 0.6791
# Epoch 51/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 1.0000
# Epoch 51: val_loss improved from 0.96075 to 0.95817, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.9582 - val_accuracy: 0.6766
# Epoch 52/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 52: val_loss improved from 0.95817 to 0.95647, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.9565 - val_accuracy: 0.6816
# Epoch 53/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 1.0000
# Epoch 53: val_loss improved from 0.95647 to 0.95323, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 15s 1s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.9532 - val_accuracy: 0.6766
# Epoch 54/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 54: val_loss improved from 0.95323 to 0.94953, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.9495 - val_accuracy: 0.6791
# Epoch 55/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000
# Epoch 55: val_loss improved from 0.94953 to 0.94908, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.9491 - val_accuracy: 0.6841
# Epoch 56/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 56: val_loss improved from 0.94908 to 0.94310, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.9431 - val_accuracy: 0.6866
# Epoch 57/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 57: val_loss improved from 0.94310 to 0.93996, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.9400 - val_accuracy: 0.6866
# Epoch 58/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 58: val_loss improved from 0.93996 to 0.93727, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.9373 - val_accuracy: 0.6866
# Epoch 59/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 59: val_loss improved from 0.93727 to 0.93536, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.9354 - val_accuracy: 0.6891
# Epoch 60/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 60: val_loss improved from 0.93536 to 0.93324, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.9332 - val_accuracy: 0.6915
# Epoch 61/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 61: val_loss improved from 0.93324 to 0.93172, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.9317 - val_accuracy: 0.6915
# Epoch 62/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 62: val_loss improved from 0.93172 to 0.93108, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.9311 - val_accuracy: 0.6891
# Epoch 63/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 63: val_loss improved from 0.93108 to 0.92756, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.9276 - val_accuracy: 0.6891
# Epoch 64/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 64: val_loss improved from 0.92756 to 0.92704, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.9270 - val_accuracy: 0.6891
# Epoch 65/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 65: val_loss did not improve from 0.92704
# 10/10 [==============================] - 13s 1s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.9275 - val_accuracy: 0.6915
# Epoch 66/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 66: val_loss improved from 0.92704 to 0.92559, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.9256 - val_accuracy: 0.6915
# Epoch 67/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 67: val_loss improved from 0.92559 to 0.92260, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.9226 - val_accuracy: 0.6940
# Epoch 68/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 68: val_loss improved from 0.92260 to 0.92014, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.9201 - val_accuracy: 0.6915
# Epoch 69/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 69: val_loss improved from 0.92014 to 0.91900, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.9190 - val_accuracy: 0.6940
# Epoch 70/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 70: val_loss improved from 0.91900 to 0.91594, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.9159 - val_accuracy: 0.6915
# Epoch 71/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 71: val_loss improved from 0.91594 to 0.91210, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9121 - val_accuracy: 0.6965
# Epoch 72/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 72: val_loss improved from 0.91210 to 0.90963, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9096 - val_accuracy: 0.6940
# Epoch 73/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 73: val_loss improved from 0.90963 to 0.90909, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.9091 - val_accuracy: 0.6940
# Epoch 74/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 74: val_loss improved from 0.90909 to 0.90777, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9078 - val_accuracy: 0.6915
# Epoch 75/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 75: val_loss improved from 0.90777 to 0.90572, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9057 - val_accuracy: 0.6915
# Epoch 76/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 76: val_loss improved from 0.90572 to 0.90462, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9046 - val_accuracy: 0.6915
# Epoch 77/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 77: val_loss improved from 0.90462 to 0.90338, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9034 - val_accuracy: 0.6915
# Epoch 78/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 78: val_loss improved from 0.90338 to 0.90312, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.9031 - val_accuracy: 0.6940
# Epoch 79/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 79: val_loss improved from 0.90312 to 0.90255, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.9025 - val_accuracy: 0.6965
# Epoch 80/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 80: val_loss improved from 0.90255 to 0.90128, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9013 - val_accuracy: 0.6990
# Epoch 81/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 81: val_loss improved from 0.90128 to 0.90061, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.9006 - val_accuracy: 0.7015
# Epoch 82/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 82: val_loss improved from 0.90061 to 0.89872, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.8987 - val_accuracy: 0.7015
# Epoch 83/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 83: val_loss improved from 0.89872 to 0.89834, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.8983 - val_accuracy: 0.6990
# Epoch 84/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 84: val_loss improved from 0.89834 to 0.89756, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.8976 - val_accuracy: 0.7040
# Epoch 85/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 85: val_loss improved from 0.89756 to 0.89748, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.8975 - val_accuracy: 0.7065
# Epoch 86/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 86: val_loss improved from 0.89748 to 0.89705, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.8970 - val_accuracy: 0.7065
# Epoch 87/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 87: val_loss improved from 0.89705 to 0.89580, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.8958 - val_accuracy: 0.7065
# Epoch 88/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.89580
# 10/10 [==============================] - 12s 1s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.8965 - val_accuracy: 0.7040
# Epoch 89/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 89: val_loss did not improve from 0.89580
# 10/10 [==============================] - 12s 1s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.8960 - val_accuracy: 0.7040
# Epoch 90/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 90: val_loss improved from 0.89580 to 0.89557, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.8956 - val_accuracy: 0.7065
# Epoch 91/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 91: val_loss improved from 0.89557 to 0.89556, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.8956 - val_accuracy: 0.7090
# Epoch 92/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 92: val_loss improved from 0.89556 to 0.89548, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.8955 - val_accuracy: 0.7090
# Epoch 93/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 93: val_loss improved from 0.89548 to 0.89510, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.8951 - val_accuracy: 0.7090
# Epoch 94/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 94: val_loss improved from 0.89510 to 0.89475, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.8948 - val_accuracy: 0.7090
# Epoch 95/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 95: val_loss improved from 0.89475 to 0.89464, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.8946 - val_accuracy: 0.7090
# Epoch 96/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 96: val_loss did not improve from 0.89464
# 10/10 [==============================] - 13s 1s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.8947 - val_accuracy: 0.7090
# Epoch 97/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 97: val_loss improved from 0.89464 to 0.89427, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.8943 - val_accuracy: 0.7114
# Epoch 98/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 0.89427
# 10/10 [==============================] - 12s 1s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.8945 - val_accuracy: 0.7090
# Epoch 99/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 99: val_loss improved from 0.89427 to 0.89426, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.8943 - val_accuracy: 0.7114
# Epoch 100/100
# 11/10 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 100: val_loss improved from 0.89426 to 0.89360, saving model to weights.best.inc.fmd_minc.hdf5
# 10/10 [==============================] - 13s 1s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.8936 - val_accuracy: 0.7114

# %% [markdown]
# ## val losses for different data augmentation
# **Final decision: add horizontal_flip=true**
#
# baseline -> 1.2373
#
# add zoom_range=0.3 -> 1.4654
#
# add brightness_range=[0.7,1.3] -> 1.3758
#
# add horizontal_flip=true -> 1.2264
#
# add rotation_range=30 -> 1.4114
#
# add zoom_range=0.3, rotation_range=30, height_shift_range=0.2, width_shift_range=0.2 -> 1.3704

# %% [markdown]
# # val losses for hyperparamter tuning (with best data augmentation setting)
#
# **Final decision: increase batch size from 32 to 128**
#
# add Dropout(0.5) before last fc layer -> 1.2156
#
# reduce hidden layer size from 1024 512 to 512 256 -> 1.2050
#
# increase num of hidden layer from 1024 512 to 1024 512 256 -> 1.1980
#
# replace SGD with Adam and lr reduced from 0.001 to 0.0001 -> 1.1868
#
# reduce batch size from 32 to 16 -> 0.9070
#
# reduce batch size from 32 to 4 -> 2.3543
#
# increase batch size from 32 to 64 -> 1.0126
#
# increase batch size from 32 to 128 -> 0.8936

# %%
import matplotlib.pyplot as plt

def plot_metric(model_, metric, save=False, save_path=None):
    train_metrics = model_.history.history[metric]
    val_metrics = model_.history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    if save:
      plt.savefig(save_path)
    plt.show()

# %%
plot_metric(model_, 'loss')

# %%
plot_metric(model_, 'accuracy')

# %% [markdown]
# # Evaluation on test data

# %%
# evaluate on fmd test data
model_.evaluate(val_datagen.flow(x_test_fmd, y_test_fmd, batch_size=batch_size))
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.8184 - accuracy: 0.7677
# [0.8184453845024109, 0.7676767706871033]

# %%
# evaluate on minc test data
model_.evaluate(val_datagen.flow(x_test_minc, y_test_minc, batch_size=batch_size))
# Out:
# 1/1 [==============================] - 0s 230ms/step - loss: 1.4295 - accuracy: 0.6364
# [1.429487943649292, 0.6363636255264282]

# %%
# evaluate on minc + fmd test data
x_test = np.concatenate((x_test_fmd, x_test_minc))
y_test = np.concatenate((y_test_fmd, y_test_minc))

model_.evaluate(val_datagen.flow(x_test, y_test, batch_size=batch_size))
# Out:
# 2/2 [==============================] - 1s 747ms/step - loss: 1.1240 - accuracy: 0.7020
# [1.1239664554595947, 0.7020202279090881]
