# %%
import os
from tqdm import tqdm
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.optimizers import SGD, Adam
from sklearn.utils import shuffle

# %%
drive.mount("/content/gdrive")
os.chdir('gdrive/MyDrive')
if not os.path.exists('CZ4042_project'):
    os.makedirs('CZ4042_project')
os.chdir('CZ4042_project')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Data acquisition
#
# Use obtain_fmd_minc_dataset.ipynb to download the FMD and MINC data to drive

# %% [markdown]
# # Load FMD data

# %%
x_train_fmd = []
y_train_fmd = []

label_map = {   
                "fabric":0,
                "foliage":1,
                "glass":2,
                "leather":3,
                "metal":4,
                "paper":5,
                "plastic":6,
                "stone":7,
                "water":8,
                "wood":9,
             }

dim = 256
dirs = os.listdir("FMD/image")
for class_dir in dirs:
  class_dir_path = os.path.join("FMD/image/", class_dir)
  num_loaded = 0
  for img_name in os.listdir(class_dir_path):
    if img_name[-3:] != 'jpg':
      continue
    img_path = os.path.join(class_dir_path, img_name)
    img = cv2.imread(img_path)
    targets = np.zeros(10)
    targets[label_map[class_dir]] = 1 
    x_train_fmd.append(cv2.resize(img, (dim, dim)))
    y_train_fmd.append(targets)
    num_loaded += 1
  print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_fmd = np.array(y_train_fmd, np.uint8)
x_train_fmd = np.array(x_train_fmd, np.float32)

# %% [markdown]
# #Split FMD data into train, val and test

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_fmd, y_train_fmd):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_fmd, x_valid_test_fmd = x_train_fmd[train_index], x_train_fmd[none_train_index]
    y_train_fmd, y_valid_test_fmd = y_train_fmd[train_index], y_train_fmd[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_fmd, y_valid_test_fmd):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_fmd, x_test_fmd = x_valid_test_fmd[val_index], x_valid_test_fmd[test_index]
    y_val_fmd, y_test_fmd = y_valid_test_fmd[val_index], y_valid_test_fmd[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # Split FMD data into train, val and test

# %%
x_train_minc = []
y_train_minc = []
num_to_load_per_class = 100 # there are 2.5k images per class, we only use 100 here

dirs = os.listdir("MINC/minc-2500/images/")
for class_dir in dirs:
  if class_dir in label_map.keys():
    class_dir_path = os.path.join("MINC/minc-2500/images/", class_dir)
    num_loaded = 0
    for img_name in os.listdir(class_dir_path):
      if img_name[-3:] != 'jpg':
        continue
      img_path = os.path.join(class_dir_path, img_name)
      img = cv2.imread(img_path)
      targets = np.zeros(10)
      targets[label_map[class_dir]] = 1 
      x_train_minc.append(cv2.resize(img, (dim, dim)))
      y_train_minc.append(targets)
      num_loaded += 1
      if num_loaded == num_to_load_per_class:
        break
    print("load {}/{} images from {}".format(num_loaded, len(os.listdir(class_dir_path)), class_dir))

y_train_minc = np.array(y_train_minc, np.uint8)
x_train_minc = np.array(x_train_minc, np.float32)
# Out:
# load 100/2500 images from paper
# load 100/2500 images from plastic
# load 100/2500 images from stone
# load 100/2500 images from water
# load 100/2500 images from wood
# load 100/2500 images from fabric
# load 100/2500 images from foliage
# load 100/2500 images from glass
# load 100/2500 images from leather
# load 100/2500 images from metal

# %% [markdown]
# # Split MINC data into train, val and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for train_index, none_train_index in sss.split(x_train_minc, y_train_minc):
    print("Using {} for training and {} for validation and test".format(len(train_index), len(none_train_index)))
    x_train_minc, x_valid_test_minc = x_train_minc[train_index], x_train_minc[none_train_index]
    y_train_minc, y_valid_test_minc = y_train_minc[train_index], y_train_minc[none_train_index]
# Out:
# Using 700 for training and 300 for validation and test

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.33, random_state=42) # StratifiedShuffleSplit ensures a balanced split for all the classes
for val_index, test_index in sss.split(x_valid_test_minc, y_valid_test_minc):
    print("Using {} for val and {} for test".format(len(val_index), len(test_index)))
    x_val_minc, x_test_minc = x_valid_test_minc[val_index], x_valid_test_minc[test_index]
    y_val_minc, y_test_minc = y_valid_test_minc[val_index], y_valid_test_minc[test_index]
# Out:
# Using 201 for val and 99 for test

# %% [markdown]
# # obtain train and val data (using only FMD train and val data)

# %%
# define final train data
x_train = x_train_fmd
y_train = y_train_fmd
del y_train_minc
del x_train_minc
del y_train_fmd
del x_train_fmd

# define final val data
x_val = x_val_fmd
y_val = y_val_fmd
del y_val_minc
del x_val_minc
del y_val_fmd
del x_val_fmd

# %% [markdown]
# # Data augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255,)
                            #height_shift_range=0.2,
                            #width_shift_range=0.2,
                            #horizontal_flip=True,
                            #rotation_range=30,
                            #brightness_range=[0.7,1.0],
                            #zoom_range=0.3)

val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # Load pretrained MobileNetV2 (imagenet)

# %%
inc_model = MobileNetV2(weights='imagenet',
                        include_top=False,
                        input_shape=(dim, dim, 3))

print("number of layers:", len(inc_model.layers))

# decide whether to freeze pretrained weights
for layer in inc_model.layers:
    layer.trainable = True
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# number of layers: 154

# %% [markdown]
# #Append custom Layers

# %%
x = inc_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
predictions = Dense(10, activation="softmax")(x)
model_ = Model(inputs=inc_model.input, outputs=predictions)

# %%
epochs = 100
learning_rate = 0.001
batch_size = 32

callbacks = [ EarlyStopping(monitor='val_loss', patience=10, verbose=1), 
              ModelCheckpoint(filepath='weights.best.inc.fmd.hdf5', verbose=1, save_best_only=True),
             #ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
            ]

# %%
# compile the model
model_.compile(optimizer=SGD(lr=learning_rate, momentum=0.9)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# # Fine tuning

# %%
# ------ TRAINING ------
model_.fit_generator(train_datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(x_train)/batch_size, 
                    validation_data=val_datagen.flow(x_val, y_val, batch_size=batch_size), 
                    validation_steps=len(x_val)/batch_size,
                    callbacks=callbacks,
                    epochs=epochs,
                    verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/100
# 22/21 [==============================] - ETA: 0s - loss: 2.4394 - accuracy: 0.1157
# Epoch 1: val_loss improved from inf to 2.11435, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 23s 464ms/step - loss: 2.4394 - accuracy: 0.1157 - val_loss: 2.1144 - val_accuracy: 0.2537
# Epoch 2/100
# 22/21 [==============================] - ETA: 0s - loss: 1.9384 - accuracy: 0.3314
# Epoch 2: val_loss improved from 2.11435 to 1.82007, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 302ms/step - loss: 1.9384 - accuracy: 0.3314 - val_loss: 1.8201 - val_accuracy: 0.4826
# Epoch 3/100
# 22/21 [==============================] - ETA: 0s - loss: 1.4502 - accuracy: 0.5886
# Epoch 3: val_loss improved from 1.82007 to 1.56834, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 307ms/step - loss: 1.4502 - accuracy: 0.5886 - val_loss: 1.5683 - val_accuracy: 0.5075
# Epoch 4/100
# 22/21 [==============================] - ETA: 0s - loss: 1.0558 - accuracy: 0.7486
# Epoch 4: val_loss improved from 1.56834 to 1.30042, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 307ms/step - loss: 1.0558 - accuracy: 0.7486 - val_loss: 1.3004 - val_accuracy: 0.6070
# Epoch 5/100
# 22/21 [==============================] - ETA: 0s - loss: 0.7452 - accuracy: 0.8157
# Epoch 5: val_loss improved from 1.30042 to 1.19406, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 311ms/step - loss: 0.7452 - accuracy: 0.8157 - val_loss: 1.1941 - val_accuracy: 0.6119
# Epoch 6/100
# 22/21 [==============================] - ETA: 0s - loss: 0.5625 - accuracy: 0.8757
# Epoch 6: val_loss improved from 1.19406 to 1.09886, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 308ms/step - loss: 0.5625 - accuracy: 0.8757 - val_loss: 1.0989 - val_accuracy: 0.6269
# Epoch 7/100
# 22/21 [==============================] - ETA: 0s - loss: 0.3950 - accuracy: 0.9186
# Epoch 7: val_loss did not improve from 1.09886
# 21/21 [==============================] - 6s 279ms/step - loss: 0.3950 - accuracy: 0.9186 - val_loss: 1.1127 - val_accuracy: 0.6119
# Epoch 8/100
# 22/21 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.9314
# Epoch 8: val_loss improved from 1.09886 to 1.02899, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 356ms/step - loss: 0.3197 - accuracy: 0.9314 - val_loss: 1.0290 - val_accuracy: 0.6468
# Epoch 9/100
# 22/21 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9600
# Epoch 9: val_loss did not improve from 1.02899
# 21/21 [==============================] - 6s 283ms/step - loss: 0.2184 - accuracy: 0.9600 - val_loss: 1.0757 - val_accuracy: 0.6318
# Epoch 10/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1822 - accuracy: 0.9771
# Epoch 10: val_loss improved from 1.02899 to 1.01531, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 356ms/step - loss: 0.1822 - accuracy: 0.9771 - val_loss: 1.0153 - val_accuracy: 0.6468
# Epoch 11/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9714
# Epoch 11: val_loss did not improve from 1.01531
# 21/21 [==============================] - 6s 284ms/step - loss: 0.1523 - accuracy: 0.9714 - val_loss: 1.1210 - val_accuracy: 0.6269
# Epoch 12/100
# 22/21 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9857
# Epoch 12: val_loss did not improve from 1.01531
# 21/21 [==============================] - 6s 287ms/step - loss: 0.1102 - accuracy: 0.9857 - val_loss: 1.0869 - val_accuracy: 0.6269
# Epoch 13/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9900
# Epoch 13: val_loss improved from 1.01531 to 1.00934, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 356ms/step - loss: 0.0898 - accuracy: 0.9900 - val_loss: 1.0093 - val_accuracy: 0.6567
# Epoch 14/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9886
# Epoch 14: val_loss did not improve from 1.00934
# 21/21 [==============================] - 6s 286ms/step - loss: 0.0833 - accuracy: 0.9886 - val_loss: 1.0166 - val_accuracy: 0.6468
# Epoch 15/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9886
# Epoch 15: val_loss did not improve from 1.00934
# 21/21 [==============================] - 6s 291ms/step - loss: 0.0747 - accuracy: 0.9886 - val_loss: 1.0377 - val_accuracy: 0.6318
# Epoch 16/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9957
# Epoch 16: val_loss did not improve from 1.00934
# 21/21 [==============================] - 6s 291ms/step - loss: 0.0616 - accuracy: 0.9957 - val_loss: 1.0471 - val_accuracy: 0.6517
# Epoch 17/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9914
# Epoch 17: val_loss did not improve from 1.00934
# 21/21 [==============================] - 6s 289ms/step - loss: 0.0586 - accuracy: 0.9914 - val_loss: 1.0330 - val_accuracy: 0.6617
# Epoch 18/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9971
# Epoch 18: val_loss improved from 1.00934 to 0.98597, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 357ms/step - loss: 0.0387 - accuracy: 0.9971 - val_loss: 0.9860 - val_accuracy: 0.6567
# Epoch 19/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9986
# Epoch 19: val_loss improved from 0.98597 to 0.97016, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 323ms/step - loss: 0.0347 - accuracy: 0.9986 - val_loss: 0.9702 - val_accuracy: 0.6617
# Epoch 20/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9971
# Epoch 20: val_loss did not improve from 0.97016
# 21/21 [==============================] - 6s 294ms/step - loss: 0.0368 - accuracy: 0.9971 - val_loss: 0.9719 - val_accuracy: 0.6716
# Epoch 21/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9971
# Epoch 21: val_loss improved from 0.97016 to 0.95653, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 357ms/step - loss: 0.0359 - accuracy: 0.9971 - val_loss: 0.9565 - val_accuracy: 0.6716
# Epoch 22/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.95653 to 0.94302, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 322ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.9430 - val_accuracy: 0.6816
# Epoch 23/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9986
# Epoch 23: val_loss improved from 0.94302 to 0.91928, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 321ms/step - loss: 0.0209 - accuracy: 0.9986 - val_loss: 0.9193 - val_accuracy: 0.6866
# Epoch 24/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9986
# Epoch 24: val_loss improved from 0.91928 to 0.91891, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 320ms/step - loss: 0.0192 - accuracy: 0.9986 - val_loss: 0.9189 - val_accuracy: 0.6866
# Epoch 25/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9957
# Epoch 25: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 291ms/step - loss: 0.0302 - accuracy: 0.9957 - val_loss: 0.9318 - val_accuracy: 0.6915
# Epoch 26/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9957
# Epoch 26: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 291ms/step - loss: 0.0215 - accuracy: 0.9957 - val_loss: 0.9528 - val_accuracy: 0.6915
# Epoch 27/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9986
# Epoch 27: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 295ms/step - loss: 0.0197 - accuracy: 0.9986 - val_loss: 0.9451 - val_accuracy: 0.7015
# Epoch 28/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 293ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.9363 - val_accuracy: 0.7065
# Epoch 29/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9986
# Epoch 29: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 292ms/step - loss: 0.0150 - accuracy: 0.9986 - val_loss: 0.9671 - val_accuracy: 0.6915
# Epoch 30/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9971
# Epoch 30: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 291ms/step - loss: 0.0205 - accuracy: 0.9971 - val_loss: 0.9559 - val_accuracy: 0.7065
# Epoch 31/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 292ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.9373 - val_accuracy: 0.7114
# Epoch 32/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.91891
# 21/21 [==============================] - 6s 292ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.9219 - val_accuracy: 0.7065
# Epoch 33/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 33: val_loss improved from 0.91891 to 0.91351, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 357ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.9135 - val_accuracy: 0.7065
# Epoch 34/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.91351
# 21/21 [==============================] - 6s 289ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.9165 - val_accuracy: 0.7065
# Epoch 35/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9971
# Epoch 35: val_loss improved from 0.91351 to 0.90544, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 369ms/step - loss: 0.0165 - accuracy: 0.9971 - val_loss: 0.9054 - val_accuracy: 0.7164
# Epoch 36/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.90544
# 21/21 [==============================] - 6s 292ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.9166 - val_accuracy: 0.7065
# Epoch 37/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9971
# Epoch 37: val_loss did not improve from 0.90544
# 21/21 [==============================] - 6s 295ms/step - loss: 0.0129 - accuracy: 0.9971 - val_loss: 0.9203 - val_accuracy: 0.6965
# Epoch 38/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.90544
# 21/21 [==============================] - 6s 294ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.9187 - val_accuracy: 0.7114
# Epoch 39/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.90544
# 21/21 [==============================] - 6s 290ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.9109 - val_accuracy: 0.7164
# Epoch 40/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9986
# Epoch 40: val_loss improved from 0.90544 to 0.90488, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 8s 368ms/step - loss: 0.0098 - accuracy: 0.9986 - val_loss: 0.9049 - val_accuracy: 0.7164
# Epoch 41/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9986
# Epoch 41: val_loss improved from 0.90488 to 0.89315, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 322ms/step - loss: 0.0100 - accuracy: 0.9986 - val_loss: 0.8931 - val_accuracy: 0.7214
# Epoch 42/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 42: val_loss improved from 0.89315 to 0.88979, saving model to weights.best.inc.fmd.hdf5
# 21/21 [==============================] - 7s 323ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.8898 - val_accuracy: 0.7313
# Epoch 43/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 290ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.8953 - val_accuracy: 0.7363
# Epoch 44/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 291ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9067 - val_accuracy: 0.7313
# Epoch 45/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9971
# Epoch 45: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 292ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.9116 - val_accuracy: 0.7363
# Epoch 46/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 287ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9602 - val_accuracy: 0.7363
# Epoch 47/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 293ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9511 - val_accuracy: 0.7463
# Epoch 48/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 293ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9281 - val_accuracy: 0.7463
# Epoch 49/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 295ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.9210 - val_accuracy: 0.7413
# Epoch 50/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9986
# Epoch 50: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 296ms/step - loss: 0.0088 - accuracy: 0.9986 - val_loss: 0.9400 - val_accuracy: 0.7363
# Epoch 51/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9986
# Epoch 51: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 296ms/step - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.9465 - val_accuracy: 0.7313
# Epoch 52/100
# 22/21 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.88979
# 21/21 [==============================] - 6s 293ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9060 - val_accuracy: 0.7363
# Epoch 52: early stopping

# %%
import matplotlib.pyplot as plt

def plot_metric(model_, metric, save=False, save_path=None):
    train_metrics = model_.history.history[metric]
    val_metrics = model_.history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    if save:
      plt.savefig(save_path)
    plt.show()

# %%
plot_metric(model_, 'loss')

# %%
plot_metric(model_, 'accuracy')

# %% [markdown]
# # Evaluation on test data

# %%
# evaluate on fmd test data
model_.evaluate(val_datagen.flow(x_test_fmd, y_test_fmd, batch_size=batch_size))
# Out:
# 4/4 [==============================] - 0s 123ms/step - loss: 1.0537 - accuracy: 0.7576
# [1.05368971824646, 0.7575757503509521]

# %%
# evaluate on minc test data
model_.evaluate(val_datagen.flow(x_test_minc, y_test_minc, batch_size=batch_size))
# Out:
# 4/4 [==============================] - 0s 44ms/step - loss: 2.4841 - accuracy: 0.3636
# [2.48408579826355, 0.3636363744735718]

# %%
# evaluate on minc + fmd test data
x_test = np.concatenate((x_test_fmd, x_test_minc))
y_test = np.concatenate((y_test_fmd, y_test_minc))

model_.evaluate(val_datagen.flow(x_test, y_test, batch_size=batch_size))
# Out:
# 7/7 [==============================] - 1s 93ms/step - loss: 1.7689 - accuracy: 0.5606
# [1.7688878774642944, 0.560606062412262]
